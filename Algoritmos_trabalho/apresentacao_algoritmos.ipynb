# %% [markdown]
# <h1>Plotagem dos algoritmos </h1>

# %% [markdown]
# Importação dos módulos para construir os gráficos

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# <h3>Gráfico dos Algoritmos Simples</h3>

# %%
sizes = [5000, 10000, 50000, 100000, 500000]

bubble_sort_times = [3.3509, 15.1669, 343.4534, 1343.6017, 8755.0000]
insertion_sort_times = [1.2760, 7.0000, 149.8476, 738.4283, 9480.0000]
selection_sort_times = [1.9600, 6.9620, 256.3533, 1576.8519, 7200.0000]

# Configurar os gráficos
plt.figure(figsize=(10, 6))

# Calcular a posição das barras no eixo x
x = range(len(sizes))

# Plotar as barras para o Bubble Sort
plt.bar(x, bubble_sort_times, label='Bubble Sort', color='red', width=0.2)

# Plotar as barras para o Insertion Sort
plt.bar([i + 0.2 for i in x], insertion_sort_times, label='Insertion Sort', color='blue', width=0.2)

# Plotar as barras para o Selection Sort
plt.bar([i + 0.4 for i in x], selection_sort_times, label='Selection Sort', color='green', width=0.2)

# Plotar uma linha conectando os pontos de dados
plt.plot(x, bubble_sort_times, marker='o', linestyle='-', color='red')
plt.plot([i + 0.2 for i in x], insertion_sort_times, marker='o', linestyle='-', color='blue')
plt.plot([i + 0.4 for i in x], selection_sort_times, marker='o', linestyle='-', color='green')

# Definir os rótulos dos eixos
plt.xlabel('Tamanho da Entrada (N)')
plt.ylabel('Tempo de Execução (s)')

# Definir os rótulos do eixo x
plt.xticks([i + 0.2 for i in x], sizes)

# Adicionar uma legenda
plt.legend()

# Exibir o gráfico
plt.show()

# %% [markdown]
# <h3>Gráfico do Algoritmo Bubble Sort</h3>

# %%
sizes = [5000, 10000, 50000, 100000, 500000]

bubble_sort_times = [3.3509, 15.1669, 343.4534, 1343.6017, 8755.0000]


# Configurar os gráficos
plt.figure(figsize=(10, 6))

# Calcular a posição das barras no eixo x
x = range(len(sizes))

# Plotar as barras para o Bubble Sort
#plt.bar(x, bubble_sort_times, label='Bubble Sort', color='red', width=0.2)

# Plotar uma linha conectando os pontos de dados
plt.plot(x, bubble_sort_times, marker='o', linestyle='-', color='red')


# Definir os rótulos dos eixos
plt.xlabel('Tamanho da Entrada (N)')
plt.ylabel('Tempo de Execução (s)')

# Definir os rótulos do eixo x
plt.xticks([i + 0.2 for i in x], sizes)


# Exibir o gráfico
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# <h3>Gráfico do Algoritmo Insertion Sort</h3>

# %%
sizes = [5000, 10000, 50000, 100000, 500000]


insertion_sort_times = [1.2760, 7.0000, 149.8476, 738.4283, 9480.0000]


# Configurar os gráficos
plt.figure(figsize=(10, 6))

# Calcular a posição das barras no eixo x
x = range(len(sizes))

# Plotar as barras para o Insertion Sort
#plt.bar([i + 0.2 for i in x], insertion_sort_times, label='Insertion Sort', color='blue', width=0.2)


# Plotar uma linha conectando os pontos de dados
plt.plot([i + 0.2 for i in x], insertion_sort_times, marker='o', linestyle='-', color='blue')


# Definir os rótulos dos eixos
plt.xlabel('Tamanho da Entrada (N)')
plt.ylabel('Tempo de Execução (s)')

# Definir os rótulos do eixo x
plt.xticks([i + 0.2 for i in x], sizes)

# Adicionar uma legenda
plt.legend()

# Exibir o gráfico
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# <h3>Gráfico do Algoritmo Selection Sort</h3>

# %%
sizes = [5000, 10000, 50000, 100000, 500000]

selection_sort_times = [1.9600, 6.9620, 256.3533, 1576.8519, 7200.0000]

# Configurar os gráficos
plt.figure(figsize=(10, 6))

# Calcular a posição das barras no eixo x
x = range(len(sizes))

# Plotar uma linha conectando os pontos de dados

plt.plot([i + 0.4 for i in x], selection_sort_times, marker='o', linestyle='-', color='green')

# Definir os rótulos dos eixos
plt.xlabel('Tamanho da Entrada (N)')
plt.ylabel('Tempo de Execução (s)')

# Definir os rótulos do eixo x
plt.xticks([i + 0.2 for i in x], sizes)

# Adicionar uma legenda
plt.legend()

# Exibir o gráfico
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# <h3>Gráficos dos Algoritmos Rápidos/Recursivos</h3>

# %%
sizes = [5000, 10000, 50000, 100000, 500000]

merge_sort_times = [0.0590, 0.0509, 0.2510, 0.9900, 4.8420]
heap_sort_times = [0.0019, 0.0070, 0.0370, 0.0840, 0.7600]
quick_ccont_pivo_times = [0.0169, 0.0469, 0.3869, 0.9009, 3.0659]
quick_scont_pivo_times = [0.0150, 0.0320, 0.3020, 0.4740, 3.3849]

# Configurar os gráficos
plt.figure(figsize=(10, 6))

# Calcular a posição das barras no eixo x
x = range(len(sizes))

# Plotar as barras para o Merge Sort
plt.bar(x, merge_sort_times, label='Merge Sort', color='red', width=0.2)

# Plotar as barras para o Heap Sort
plt.bar([i + 0.2 for i in x], heap_sort_times, label='Heap Sort', color='blue', width=0.2)

# Plotar as barras para o Quick Sort c/controle
plt.bar([i + 0.4 for i in x], quick_ccont_pivo_times, label='Quick Sort c/controle', color='green', width=0.2)

# Plotar as barras para o Quick Sort s/controle
plt.bar([i + 0.6 for i in x], quick_scont_pivo_times, label='Quick Sort s/controle', color='yellow', width=0.2)

# Plotar uma linha conectando os pontos de dados
plt.plot(x, merge_sort_times, marker='o', linestyle='-', color='red')
plt.plot([i + 0.2 for i in x], heap_sort_times, marker='o', linestyle='-', color='blue')
plt.plot([i + 0.4 for i in x], quick_ccont_pivo_times, marker='o', linestyle='-', color='green')
plt.plot([i + 0.6 for i in x], quick_scont_pivo_times, marker='o', linestyle='-', color='yellow')

# Definir os rótulos dos eixos
plt.xlabel('Tamanho da Entrada (N)')
plt.ylabel('Tempo de Execução (s)')

# Definir os rótulos do eixo x
plt.xticks([i + 0.2 for i in x], sizes)

# Adicionar uma legenda
plt.legend()

# Exibir o gráfico
plt.show()

# %% [markdown]
# <h3>Gráfico do Algoritmo Merge Sort</h3>

# %%
sizes = [5000, 10000, 50000, 100000, 500000]

merge_sort_times = [0.0590, 0.0509, 0.2510, 0.9900, 4.8420]


# Configurar os gráficos
plt.figure(figsize=(10, 6))

# Calcular a posição das barras no eixo x
x = range(len(sizes))

# Plotar uma linha conectando os pontos de dados
plt.plot(x, merge_sort_times, marker='o', linestyle='-', color='red')

# Definir os rótulos dos eixos
plt.xlabel('Tamanho da Entrada (N)')
plt.ylabel('Tempo de Execução (s)')

# Definir os rótulos do eixo x
plt.xticks([i + 0.2 for i in x], sizes)

# Adicionar uma legenda
plt.legend()

# Exibir o gráfico
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# <h3>Gráfico do Algoritmo Heap Sort</h3>

# %%
sizes = [5000, 10000, 50000, 100000, 500000]

heap_sort_times = [0.0019, 0.0070, 0.0370, 0.0840, 0.7600]


# Configurar os gráficos
plt.figure(figsize=(10, 6))

# Calcular a posição das barras no eixo x
x = range(len(sizes))


# Plotar uma linha conectando os pontos de dados

plt.plot([i + 0.2 for i in x], heap_sort_times, marker='o', linestyle='-', color='blue')


# Definir os rótulos dos eixos
plt.xlabel('Tamanho da Entrada (N)')
plt.ylabel('Tempo de Execução (s)')

# Definir os rótulos do eixo x
plt.xticks([i + 0.2 for i in x], sizes)

# Adicionar uma legenda
plt.legend()

# Exibir o gráfico
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# <h3>Gráfico do Algoritmo Quick Sort c/controle de pivô</h3>

# %%
sizes = [5000, 10000, 50000, 100000, 500000]

quick_ccont_pivo_times = [0.0169, 0.0469, 0.3869, 0.9009, 3.0659]

# Configurar os gráficos
plt.figure(figsize=(10, 6))

# Calcular a posição das barras no eixo x
x = range(len(sizes))


# Plotar uma linha conectando os pontos de dados
plt.plot([i + 0.4 for i in x], quick_ccont_pivo_times, marker='o', linestyle='-', color='green')


# Definir os rótulos dos eixos
plt.xlabel('Tamanho da Entrada (N)')
plt.ylabel('Tempo de Execução (s)')

# Definir os rótulos do eixo x
plt.xticks([i + 0.2 for i in x], sizes)

# Adicionar uma legenda
plt.legend()

# Exibir o gráfico
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# <h3>Gráfico do Algoritmo Quick Sort s/controle de pivô</h3>

# %%
sizes = [5000, 10000, 50000, 100000, 500000]

quick_scont_pivo_times = [0.0150, 0.0320, 0.3020, 0.4740, 3.3849]

# Configurar os gráficos
plt.figure(figsize=(10, 6))

# Calcular a posição das barras no eixo x
x = range(len(sizes))

# Plotar uma linha conectando os pontos de dados
plt.plot([i + 0.6 for i in x], quick_scont_pivo_times, marker='o', linestyle='-', color='yellow')

# Definir os rótulos dos eixos
plt.xlabel('Tamanho da Entrada (N)')
plt.ylabel('Tempo de Execução (s)')

# Definir os rótulos do eixo x
plt.xticks([i + 0.2 for i in x], sizes)

# Adicionar uma legenda
plt.legend()

# Exibir o gráfico
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
